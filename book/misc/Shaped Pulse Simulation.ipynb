# %% [markdown]
# # QuTiP Simulation

# %%
import numpy as np
import matplotlib.pyplot as plt
import qutip as qt
import qctrlvisualizer as qv

plt.style.use(qv.get_qctrl_style())
plt.style.use("ggplot")

# %% [markdown]
# ## 1-qubit

# %% [markdown]
# $$
# H = \frac{\delta}{2} \sigma_z + \frac{\Omega(t)}{2} \sigma_x
# $$

# %%
T = 1.0
THETA = np.pi
detunings = np.linspace(-10, 10, 200)


def flat_pulse(t, args):
    return THETA / T


def gaussian_pulse(t, args):
    mu = 0.5 * T
    sigma = T / 6
    return (
        THETA
        / (np.sqrt(2 * np.pi) * sigma)
        * np.exp(-((t - mu) ** 2) / (2 * sigma**2))
    )


def hamiltonian(detuning, pulse):
    return [
        0.5 * THETA * detuning * qt.sigmaz(),
        [0.5 * qt.sigmax(), pulse],
    ]


def simulate_one_qubit(hamiltonian, times, initial_state):
    initial_state = qt.Qobj(initial_state)
    propagators = [qt.propagator(hamiltonian, t) for t in times]
    states = [U * initial_state for U in propagators]
    states = np.array(states).squeeze()
    qv.display_bloch_sphere(states)


def plot_profile(pulse):
    times = np.linspace(0, T, 2)
    initial_state = qt.basis(2, 0)

    e_x = []
    e_y = []
    e_z = []
    for detuning in detunings:
        result = qt.sesolve(
            hamiltonian(detuning, pulse),
            initial_state,
            times,
            [
                qt.sigmax(),
                qt.sigmay(),
                qt.sigmaz(),
            ],
        )
        e_x.append(result.expect[0][-1])
        e_y.append(result.expect[1][-1])
        e_z.append(result.expect[2][-1])

    # plt.plot(detunings, e_x, label=r"$\langle\sigma_x\rangle$")
    plt.plot(detunings, e_y, label=r"$\langle\sigma_y\rangle$")
    plt.plot(detunings, e_z, label=r"$\langle\sigma_z\rangle$")
    plt.xlabel("Detuning")
    plt.ylabel("Expectation value")
    plt.legend()

# %% [markdown]
# ### Flat
#
# $$
# \begin{aligned}
# \Omega(t) &= \frac{\pi}{T}
# \end{aligned}
# $$

# %%
plot_profile(flat_pulse)

# %%
simulate_one_qubit(
    hamiltonian(1, flat_pulse),
    np.linspace(0, T, 30),
    qt.basis(2, 0),
)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-710095e078d94662bf3696503b244b1a"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-710095e078d94662bf3696503b244b1a"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-710095e078d94662bf3696503b244b1a"
#         >Play</button>
#     </div>

# %%
result = qt.sesolve(
    hamiltonian(1, flat_pulse),
    qt.basis(2, 0),
    np.linspace(0, T, 30),
)
qv.display_bloch_sphere(np.array(result.states).squeeze())
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-bb4ca2feee3a4be1a57f7ff5245f2074"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-bb4ca2feee3a4be1a57f7ff5245f2074"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-bb4ca2feee3a4be1a57f7ff5245f2074"
#         >Play</button>
#     </div>

# %%
result.solver
# Out:
# 'sesolve'

# %% [markdown]
# ### Gaussian
#
# $$
# \begin{aligned}
# \Omega(t) &= \frac{\pi}{\sqrt{2\pi}\sigma}  e^{-\frac{(t - \mu)^2}{2\sigma^2}}
# \end{aligned}
# $$

# %%
plot_profile(gaussian_pulse)

# %%
simulate_one_qubit(
    hamiltonian(1, gaussian_pulse),
    np.linspace(0, T, 30),
    qt.basis(2, 0),
)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-ff226fea0652423987b8738bdcefbe10"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-ff226fea0652423987b8738bdcefbe10"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-ff226fea0652423987b8738bdcefbe10"
#         >Play</button>
#     </div>
