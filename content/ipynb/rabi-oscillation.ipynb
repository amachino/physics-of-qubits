# %% [markdown]
# # Rabi Oscillation
#
# ## Hamiltonian
#
# $$
# H = \omega_q a^\dagger a + \frac{1}{2} \left( \gamma a^\dagger + \gamma^* a \right)
# $$
#
# $$
# \gamma = \Omega e^{-i \omega_d t}
# $$

# %%
import numpy as np
import qutip as qt
import qctrlvisualizer as qv


def simulate_rabi(
    omega_q: float,
    omega_d: float,
    Omega: complex,
    T: float,
    dt: float,
):
    n_steps = int(T / dt)
    t = np.linspace(0.0, T, n_steps)
    gamma = Omega * np.ones_like(t, dtype=np.complex128)
    gamma *= np.exp(-1j * omega_d * t)
    a = qt.destroy(2)
    ad = a.dag()
    H = [
        omega_q * ad * a,
        [0.5 * ad, gamma],
        [0.5 * a, np.conj(gamma)],
    ]
    psi_0 = qt.basis(2, 0)
    result = qt.sesolve(
        H,
        psi_0,
        t,
    )
    states = np.array(result.states).squeeze()
    qv.display_bloch_sphere(states)

# %% [markdown]
# ## 1. on-resonance
#
# - $ \omega_q = \omega_d = 10 \times 2 \pi $
# - $ \Omega = \pi $
# - $ T = 1 $

# %%
simulate_rabi(
    omega_q=10.0 * (2 * np.pi),
    omega_d=10.0 * (2 * np.pi),
    Omega=np.pi,
    T=1.0,
    dt=0.01,
)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-9cca2901ddc84547887fb0209e2f965d"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-9cca2901ddc84547887fb0209e2f965d"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-9cca2901ddc84547887fb0209e2f965d"
#         >Play</button>
#     </div>

# %% [markdown]
# ## 2. on-resonance
#
# - $ \omega_q = \omega_d = 10 \times 2 \pi $
# - $ \Omega = \pi $
# - $ T = 2 $

# %%
simulate_rabi(
    omega_q=10 * (2 * np.pi),
    omega_d=10 * (2 * np.pi),
    Omega=np.pi,
    T=2.0,
    dt=0.01,
)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-35b78cde5d62428d81afcabcb09c73e2"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-35b78cde5d62428d81afcabcb09c73e2"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-35b78cde5d62428d81afcabcb09c73e2"
#         >Play</button>
#     </div>

# %% [markdown]
# ## 3. off-resonance
#
# - $ \omega_q = 10 \times 2 \pi $
# - $ \omega_d = 20 \times 2 \pi $
# - $ \delta = \omega_d - \omega_q = 10 \times 2 \pi $
# - $ \Omega = \pi $
# - $ T = 1 $

# %%
simulate_rabi(
    omega_q=10.0 * (2 * np.pi),
    omega_d=20.0 * (2 * np.pi),
    Omega=np.pi,
    T=1.0,
    dt=0.01,
)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-540bbc61f3654bf6ac9e1c0d0ab7ba0b"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-540bbc61f3654bf6ac9e1c0d0ab7ba0b"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-540bbc61f3654bf6ac9e1c0d0ab7ba0b"
#         >Play</button>
#     </div>

# %% [markdown]
# ## 4. off-resonance
#
# - $ \omega_q = 10 \times 2 \pi $
# - $ \omega_d = 11 \times 2 \pi $
# - $ \delta = \omega_d - \omega_q = 1 \times 2 \pi $
# - $ \Omega = \pi $
# - $ T = 1 $

# %%
simulate_rabi(
    omega_q=10.0 * (2 * np.pi),
    omega_d=11.0 * (2 * np.pi),
    Omega=np.pi,
    T=1.0,
    dt=0.01,
)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-9d140806413045d6ba2e2605a2bd9e55"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-9d140806413045d6ba2e2605a2bd9e55"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-9d140806413045d6ba2e2605a2bd9e55"
#         >Play</button>
#     </div>

# %% [markdown]
# ## 5. off-resonance
#
# - $ \omega_q = 0 \times 2 \pi $
# - $ \omega_d = 1 \times 2 \pi $
# - $ \delta = \omega_d - \omega_q = 1 \times 2 \pi $
# - $ \Omega = \pi $
# - $ T = 1 $

# %%
simulate_rabi(
    omega_q=0.0 * (2 * np.pi),
    omega_d=1.0 * (2 * np.pi),
    Omega=np.pi,
    T=1.0,
    dt=0.01,
)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-b7e740842d394b338663f753c59e7065"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-b7e740842d394b338663f753c59e7065"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-b7e740842d394b338663f753c59e7065"
#         >Play</button>
#     </div>

# %% [markdown]
# ## 6. off-resonance
#
# - $ \omega_q = -1 \times 2 \pi $
# - $ \omega_d = 0 \times 2 \pi $
# - $ \delta = \omega_d - \omega_q = 1 \times 2 \pi $
# - $ \Omega = \pi $
# - $ T = 1 $

# %%
simulate_rabi(
    omega_q=-1.0 * (2 * np.pi),
    omega_d=0.0 * (2 * np.pi),
    Omega=np.pi,
    T=1.0,
    dt=0.01,
)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-09268d60499141b0b8b5cc343a5e7648"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-09268d60499141b0b8b5cc343a5e7648"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-09268d60499141b0b8b5cc343a5e7648"
#         >Play</button>
#     </div>
