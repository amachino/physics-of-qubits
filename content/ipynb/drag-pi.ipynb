# %% [markdown]
# # DRAG π Pulse

# %%
import numpy as np
import numpy.typing as npt
import matplotlib.pyplot as plt
import qutip as qt
import qctrlvisualizer as qv


class Simulator:
    def __init__(
        self,
        dimension: int = 2,
        sampling_period: float = 1.0,
        detuning: float = 0.0,
        anharmonicity: float = 0.0,
    ):
        self.dimension = dimension
        self.sampling_period = sampling_period
        self.detuning = detuning
        self.anharmonicity = anharmonicity

    def simulate(self, waveform: npt.NDArray[np.complex128]):
        samples = np.array(waveform, dtype=np.complex128)
        samples = np.append(samples, samples[-1])
        n_samples = len(samples)
        duraiton = (n_samples - 1) * self.sampling_period
        times = np.linspace(0.0, duraiton, n_samples)
        omega = 2 * np.pi * self.detuning
        alpha = 2 * np.pi * self.anharmonicity
        a = qt.destroy(self.dimension)
        ad = a.dag()
        hamiltonian = []
        hamiltonian.append(omega * ad * a)
        hamiltonian.append(0.5 * alpha * ad * ad * a * a)
        hamiltonian.append([0.5 * ad, samples])
        hamiltonian.append([0.5 * a, np.conj(samples)])
        initial_state = qt.basis(self.dimension, 0)
        result = qt.mesolve(
            hamiltonian,
            initial_state,
            times,
        )
        return result

    def plot_waveform(self, waveform: npt.NDArray[np.complex128]):
        samples = np.array(waveform, dtype=np.complex128)
        n_samples = len(samples)
        duraiton = n_samples * self.sampling_period
        times = np.linspace(0.0, duraiton, n_samples)
        plt.plot(times, np.real(samples), label="I")
        plt.plot(times, np.imag(samples), label="Q")
        plt.xlabel("Time")
        plt.ylabel("Amplitude")
        plt.legend()
        plt.grid()

    def display_bloch_sphere(self, result):
        states = np.array(result.states).squeeze()
        qv.display_bloch_sphere(states[:, :2])

    def plot_populations(self, result):
        states = np.array(result.states).squeeze()
        populations = np.abs(states) ** 2
        qv.plot_population_dynamics(
            sample_times=result.times,
            populations={
                rf"$|{k}\rangle$": populations[:, k] for k in range(self.dimension)
            },
        )

    def print_final_populations(self, result):
        states = np.array(result.states).squeeze()
        populations = np.abs(states[-1]) ** 2
        for k in range(self.dimension):
            print(f"|{k}> : {populations[k]:>6.2%}")

    def rect_pulse(
        self,
        duration: float,
        amplitude: float,
    ) -> npt.NDArray[np.complex128]:
        length = int(duration / self.sampling_period)
        t = np.linspace(0.0, duration, length)
        values = amplitude * np.ones_like(t, dtype=np.complex128)
        return values

    def gaussian_pulse(
        self,
        duration: float,
        amplitude: float,
    ) -> npt.NDArray[np.complex128]:
        length = int(duration / self.sampling_period)
        t = np.linspace(0.0, duration, length)
        sigma = duration / 6
        mu = duration / 2
        values = np.exp(-((t - mu) ** 2) / sigma**2)
        values = values / (np.sum(values) * self.sampling_period)
        values = amplitude * values
        return values

    def drag_pulse(
        self,
        duration: float,
        amplitude: float,
        factor: float,
    ) -> npt.NDArray[np.complex128]:
        length = int(duration / self.sampling_period)
        t = np.linspace(0.0, duration, length)
        sigma = duration / 6
        mu = duration / 2
        real = np.exp(-((t - mu) ** 2) / sigma**2)
        real = real / (np.sum(real) * self.sampling_period)
        real = amplitude * real
        alpha = 2 * np.pi * self.anharmonicity
        beta = -factor / alpha
        imag = beta * (mu - t) / sigma**2 * real
        return real + 1j * imag

# %%
simulator = Simulator(
    sampling_period=0.1,
    dimension=3,
    detuning=0.0,
    anharmonicity=-0.3,
)

# %%
rotation_angle = np.pi
pulse_duration = 10
repeat_count = 4

# %% [markdown]
# ## Gaussian

# %%
pulse = simulator.gaussian_pulse(
    duration=pulse_duration,
    amplitude=rotation_angle,
)
simulator.plot_waveform(pulse)

# %%
result = simulator.simulate(pulse)
simulator.display_bloch_sphere(result)
simulator.plot_populations(result)
simulator.print_final_populations(result)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-488a5694bb414237aed12872a3453d29"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-488a5694bb414237aed12872a3453d29"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-488a5694bb414237aed12872a3453d29"
#         >Play</button>
#     </div>
# |0> :  5.08%
# |1> : 92.39%
# |2> :  2.53%

# %%
pulse_repeated = np.tile(pulse, repeat_count)
simulator.plot_waveform(pulse_repeated)

# %%
result = simulator.simulate(pulse_repeated)
simulator.display_bloch_sphere(result)
simulator.plot_populations(result)
simulator.print_final_populations(result)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-942217c4b6944a26a4f10b62ca003630"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-942217c4b6944a26a4f10b62ca003630"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-942217c4b6944a26a4f10b62ca003630"
#         >Play</button>
#     </div>
# |0> : 80.30%
# |1> :  2.44%
# |2> : 17.26%

# %% [markdown]
# ## DRAG

# %%
pulse = simulator.drag_pulse(
    duration=pulse_duration,
    amplitude=rotation_angle,
    factor=1,
)
simulator.plot_waveform(pulse)

# %%
result = simulator.simulate(pulse)
simulator.display_bloch_sphere(result)
simulator.plot_populations(result)
simulator.print_final_populations(result)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-2d2dc407c138405693e2199e82ce2ee5"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-2d2dc407c138405693e2199e82ce2ee5"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-2d2dc407c138405693e2199e82ce2ee5"
#         >Play</button>
#     </div>
# |0> :  0.15%
# |1> : 99.32%
# |2> :  0.53%

# %%
pulse_repeated = np.tile(pulse, repeat_count)
simulator.plot_waveform(pulse_repeated)

# %%
result = simulator.simulate(pulse_repeated)
simulator.display_bloch_sphere(result)
simulator.plot_populations(result)
simulator.print_final_populations(result)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-70d470387c9e409fb7d941fe004e1759"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-70d470387c9e409fb7d941fe004e1759"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-70d470387c9e409fb7d941fe004e1759"
#         >Play</button>
#     </div>
# |0> : 95.42%
# |1> :  1.60%
# |2> :  2.98%

# %% [markdown]
# ## Half-DRAG

# %%
pulse = simulator.drag_pulse(
    duration=pulse_duration,
    amplitude=rotation_angle,
    factor=0.5,
)
simulator.plot_waveform(pulse)

# %%
result = simulator.simulate(pulse)
simulator.display_bloch_sphere(result)
simulator.plot_populations(result)
simulator.print_final_populations(result)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-f737376c45f74a14a3d70366256a7e62"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-f737376c45f74a14a3d70366256a7e62"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-f737376c45f74a14a3d70366256a7e62"
#         >Play</button>
#     </div>
# |0> :  1.22%
# |1> : 97.47%
# |2> :  1.31%

# %%
pulse_repeated = np.tile(pulse, repeat_count)
simulator.plot_waveform(pulse_repeated)

# %%
result = simulator.simulate(pulse_repeated)
simulator.display_bloch_sphere(result)
simulator.plot_populations(result)
simulator.print_final_populations(result)
# Out:
#     <div
#         class="qctrlvisualizer"
#         style="display:flex;flex-direction:column;align-items:center;"
#     >
#         <div
#             class="qctrlvisualizer-wrapper"
#             style="width:300px;height:300px;margin:0.5rem 0"
#             id="qctrlvisualizer-wrapper-477c80c4d1514583949ff4af7ea5f694"
#         ></div>
#         <input
#             class="qctrlvisualizer-progress-bar"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-progress-bar-477c80c4d1514583949ff4af7ea5f694"
#             type="range"
#             min="0"
#             max="1"
#             step="0.01"
#             value="0"
#         >
#         <button
#             class="qctrlvisualizer-button qctrlvisualizer-button-play"
#             style="margin:0.5rem 0"
#             id="qctrlvisualizer-button-477c80c4d1514583949ff4af7ea5f694"
#         >Play</button>
#     </div>
# |0> : 89.84%
# |1> :  1.78%
# |2> :  8.38%
